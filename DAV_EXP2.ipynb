# %% [markdown]
# <a href="https://colab.research.google.com/github/vedantrk/DAV-SEM6/blob/main/DAV_EXP2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Experiment 2

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv('/content/tvmarketing.csv')

# Display summary
print(df.head())
print(df.info())
print(df.describe())
# Out:
#       TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TV      200 non-null    float64
#  1   Sales   200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.2 KB
# None
#                TV       Sales
# count  200.000000  200.000000
# mean   147.042500   14.022500
# std     85.854236    5.217457
# min      0.700000    1.600000
# 25%     74.375000   10.375000
# 50%    149.750000   12.900000
# 75%    218.825000   17.400000
# max    296.400000   27.000000

# %%
sns.histplot(df['Sales'], kde=True)
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %%
sns.scatterplot(x='TV', y='Sales', data=df)
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['TV']], df['Sales'], test_size=0.2, random_state=42)
model = LinearRegression()
model.fit(X_train, y_train)
predictions = model.predict(X_test)

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, predictions))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, predictions))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# Mean Absolute Error: 2.444420003751042
# Mean Squared Error: 10.204654118800956
# Root Mean Squared Error: 3.194472431998898

# %%
plt.scatter(X_test, y_test, color='black')
plt.plot(X_test, predictions, color='blue', linewidth=3)
plt.xlabel('Independent Variable')
plt.ylabel('Dependent Variable')
plt.title('Simple Linear Regression')
plt.show()

# %% [markdown]
# CONCLUSION:
# *   Understood the concept of Simple Linear Regression
# *   Explored the packages
# *  Performed Simple Linear Regression using the Libraries in Python and R
